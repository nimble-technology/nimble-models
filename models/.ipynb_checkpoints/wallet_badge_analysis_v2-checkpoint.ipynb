# %% [markdown]
# ### Imports

# %%
from collections.abc import Iterator
from datetime import date, timedelta
from web3 import Web3
 
import boto3
import botocore
import logging
import numpy as np
import os
import pandas as pd
import seaborn as sns
import string

# %%
user_local_path = "../data"
os.system('mkdir -p ../data/nft-token-transfers')
# Out:
# 0

# %%
def iterate_dates(start_date: date, end_date: date) -> Iterator:
    '''Yields date in range of [start_date, end_date]

    Args:
        start_date: inclusive start date
        end_date: inclusive end date
    '''
    for n in range(int((end_date - start_date).days)+1):
        yield start_date + timedelta(n)

        
def download_nft_transfers(start_date: date, end_date: date, local_path: string) -> None:
    '''Downloads nft token transfer data from start_date to end_date

    Args:
        start_date: inclusive start date
        end_date: inclusive end date
        local_path: download path

    Raises:
        FileNotFoundError: if local_path does not exist
    '''
    
    if not os.path.exists(local_path):
        raise FileNotFoundError(f"The {local_path} does not exist")

    s3_client = boto3.client('s3')
    bucket_name = "nimble-data-warehouse-dev"
    for download_date in iterate_dates(start_date, end_date):
        str_date = download_date.strftime("%Y-%m-%d")
        remote_path = f"etl/ethereum/nft_token_transfers/date={str_date}/nft_token_transfers.csv"
        fname = os.path.join(local_path, f"nft_token_transfers={str_date}.csv")
        if not os.path.exists(fname):
            try:
                s3_client.download_file(bucket_name, remote_path, fname)
                logging.info(f"{remote_path} downloaded")
            except botocore.exceptions.ClientError as error:
                logging.error(f'{remote_path} not found')
            except botocore.exceptions.ParamValidationError as error:
                logging.error('The parameters you provided are incorrect: {}'.format(error))

                
def convert_value_from_wei(transfers: pd.DataFrame, unit: string) -> pd.DataFrame:
    '''Convert value in WEI to unit for transfers
        where possible units are 'kwei', 'mwei', 'gwei', 'microether', 'milliether', 'ether'

    Args:
        transfers: dataframe you want to convert the value of
        unit: unit to convert to

    Returns:
        a new dataframe with converted value

    Raises:
        ValueError if unit is not valid
    '''
    if unit not in ['kwei', 'mwei', 'gwei', 'microether', 'milliether', 'ether']:
        raise ValueError("Invalid unit")
    values_in_ether = transfers['value'].apply(lambda x: float(Web3.from_wei(int(x), unit)))
    transfers['value'] = values_in_ether
    return transfers


def load_transfer_data(start_date: date, end_date: date, local_path: string) -> pd.DataFrame:
    """Loads NFT token transfer data with value in ether from start_date to end_date

    Args:
        start_date: an inclusive start date for nft token transfers
        end_date: an inclusive end date for nft token transfers
        local_path: a local path where the nft toke transfer date is located
    
    Returns:
        concatenated transfers dataframe for [start_date, end_date]

    Raises:
        ValueError: if start_date is greater than end_date
        FileNotFoundError: if local_path does not exist or if no csv file is found in the local_path
    """
    if not os.path.exists(local_path):
        raise FileNotFoundError("The local_path does not exist")
    if start_date > end_date:
        raise ValueError("The 'end_date' should be equal to or greather than 'start_date'")

    transfers_list = []
    for date_ in iterate_dates(start_date, end_date):
        fname = os.path.join(local_path, "nft_token_transfers={}.csv".format(date_.strftime("%Y-%m-%d")))
        if os.path.exists(fname):
            transfers = pd.read_csv(fname, low_memory=False)
            transfers = convert_value_from_wei(transfers, 'ether')
            transfers_list.append(transfers)
        else:
            logging.error(f"{fname} does not exist")
    
    if transfers_list:
        return pd.concat(transfers_list, ignore_index=True)
    else:
        raise FileNotFoundError(f"No csv file was loaded from {local_path}")

# %% [markdown]
# ### Load data

# %%
end_date = date(2022,10,25)
start_date = end_date - timedelta(days=30)
local_path = user_local_path + "/nft-token-transfers"
download_nft_transfers(start_date, end_date, local_path)

# %% [markdown]
# ### Compare 2 loading methods

# %%
# %%time
df = load_transfer_data(start_date, end_date, local_path)
# Out:
# CPU times: user 42.8 s, sys: 3.5 s, total: 46.3 s
# Wall time: 46.4 s

# %%
start_date
# Out:
# datetime.date(2022, 9, 25)

# %%
end_date
# Out:
# datetime.date(2022, 10, 25)

# %%
df
# Out:
#          amount                                         block_hash  \
# 0             1  0x438a438a9dffff20e3c5c3e618bf21aaf19b1a0b7bf5...
# 1             1  0x438a438a9dffff20e3c5c3e618bf21aaf19b1a0b7bf5...
# 2             1  0x438a438a9dffff20e3c5c3e618bf21aaf19b1a0b7bf5...
# 3             1  0x438a438a9dffff20e3c5c3e618bf21aaf19b1a0b7bf5...
# 4             1  0x438a438a9dffff20e3c5c3e618bf21aaf19b1a0b7bf5...
# ...         ...                                                ...
# 12469142      1  0x75ac773ba895f9f137f9e6ff6dd72306ed19448c83e5...
# 12469143      1  0x75ac773ba895f9f137f9e6ff6dd72306ed19448c83e5...
# 12469144      1  0x75ac773ba895f9f137f9e6ff6dd72306ed19448c83e5...
# 12469145      1  0x75ac773ba895f9f137f9e6ff6dd72306ed19448c83e5...
# 12469146      1  0x75ac773ba895f9f137f9e6ff6dd72306ed19448c83e5...
#
#           block_number           block_timestamp contract_type  \
# 0             15613826  2022-09-25T23:59:47.000Z        ERC721
# 1             15613826  2022-09-25T23:59:47.000Z        ERC721
# 2             15613826  2022-09-25T23:59:47.000Z        ERC721
# 3             15613826  2022-09-25T23:59:47.000Z        ERC721
# 4             15613826  2022-09-25T23:59:47.000Z        ERC721
# ...                ...                       ...           ...
# 12469142      15821368  2022-10-24T23:59:59.000Z        ERC721
# 12469143      15821368  2022-10-24T23:59:59.000Z        ERC721
# 12469144      15821368  2022-10-24T23:59:59.000Z        ERC721
# 12469145      15821368  2022-10-24T23:59:59.000Z        ERC721
# 12469146      15821368  2022-10-24T23:59:59.000Z        ERC721
#
#                                         from_address  log_index operator  \
# 0         0x0000000000000000000000000000000000000000      239.0      NaN
# 1         0x0000000000000000000000000000000000000000      238.0      NaN
# 2         0x0eee3a65abd51492ae9ac5c43046cfb9799cc66a      193.0      NaN
# 3         0x28701e73d358aa0ab40c2078ece3bf7d56948618      178.0      NaN
# 4         0x0000000000000000000000000000000000000000      175.0      NaN
# ...                                              ...        ...      ...
# 12469142  0x3a7a1cfa5ae8ef3e0f7ab5689c4804ec34edd52f      102.0      NaN
# 12469143  0x8ce003fa2767fcbb35bf801f7eeb6a4b9eb0ec9e       98.0      NaN
# 12469144  0xcda72070e455bb31c7690a170224ce43623d0b6f       93.0      NaN
# 12469145  0x0000000000000000000000000000000000000000       85.0      NaN
# 12469146  0x0000000000000000000000000000000000000000       83.0      NaN
#
#                                           to_address  \
# 0         0xc6bdfd67f722298332969c52f1c1215398f4ec22
# 1         0xc6bdfd67f722298332969c52f1c1215398f4ec22
# 2         0x1240b283c420621015f69f292d8fdb523a52772e
# 3         0xff452cc8ff7deb713b6cf5ac5aa6085c0a606786
# 4         0x685fbcf87d20ce3668f8b85ae61fbe54cce32114
# ...                                              ...
# 12469142  0xb1a5e908cbaabfea9f0baada6614583d03b74b08
# 12469143  0xa5c90a02f955e02c21b29060d5f8a9725b50f2b2
# 12469144  0xee432788ab11935ab66e5a71b8ecc333694957ac
# 12469145  0xd43a279416b96702bb8be822cc5c570d5e4467a3
# 12469146  0x16a9cd84494ce80186b7733026fd1b5e5eeb6086
#
#                                        token_address      token_id  \
# 0         0xd4621d73a6c63dd5616b97c9045dfc50a4cc3233          7095
# 1         0xd4621d73a6c63dd5616b97c9045dfc50a4cc3233          7094
# 2         0xd1169e5349d1cb9941f3dcba135c8a4b9eacfdde  171000100996
# 3         0x79471bb4cbb351a17fa1eadb5b77aa76795c423a          1810
# 4         0x7bdfec34c329b47542038114ae82d3f89aad5c13           425
# ...                                              ...           ...
# 12469142  0xd88b8b8c45a0531229dbbf93b8c503bfbe17e86a          1286
# 12469143  0x1c3ec75c53eca5acf20b0a64bab2c6d163bb08cf           647
# 12469144  0xf8e37640d57b5719f14452c8afc29e50606e36c1            55
# 12469145  0xb4fedc003053c22ac8b808bb424f3e1787f30cf2         16640
# 12469146  0xb4fedc003053c22ac8b808bb424f3e1787f30cf2         16639
#
#                                            transaction_hash  \
# 0         0x37a0540d90b6d5b71998ec2cdc037cae68a3c0ace690...
# 1         0x37a0540d90b6d5b71998ec2cdc037cae68a3c0ace690...
# 2         0xacfbbfe5ef26c3e70114709bf06e4a58c7eda6a3e384...
# 3         0xa9b2d9ae04c6703044ed192253299b5fc532b3beab72...
# 4         0xae7d438982513b2044fc7ca670df81c1894ac114eb36...
# ...                                                     ...
# 12469142  0x01f94a9ac8ba5410e2dde6dbec6fb883b0075ef0b3e1...
# 12469143  0xd2ff47427a019fa74a6374b10b7ce150df05e0182ab0...
# 12469144  0x43fe01954da65a133d9487ed9b75e553ebe66951f33c...
# 12469145  0x37b97b0e222e268cc25235f74221aab6f1af2acc5736...
# 12469146  0xe6504ef6163a7ad95d66d0c0b9525401962b398beb00...
#
#           transaction_index transaction_type    value  verified  is_batch
# 0                      69.0           Single  0.00000         1      True
# 1                      69.0           Single  0.00000         1      True
# 2                      55.0           Single  0.58999         1     False
# 3                      50.0           Single  0.01870         1     False
# 4                      49.0           Single  0.00000         1      True
# ...                     ...              ...      ...       ...       ...
# 12469142               35.0           Single  0.03800         1     False
# 12469143               29.0           Single  0.00740         1     False
# 12469144               27.0           Single  0.01000         1     False
# 12469145               22.0           Single  0.00000         1     False
# 12469146               20.0           Single  0.00000         1     False
#
# [12469147 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12469147 entries, 0 to 12469146
# Data columns (total 17 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   amount             object
#  1   block_hash         object
#  2   block_number       int64
#  3   block_timestamp    object
#  4   contract_type      object
#  5   from_address       object
#  6   log_index          float64
#  7   operator           object
#  8   to_address         object
#  9   token_address      object
#  10  token_id           object
#  11  transaction_hash   object
#  12  transaction_index  float64
#  13  transaction_type   object
#  14  value              float64
#  15  verified           int64
#  16  is_batch           bool
# dtypes: bool(1), float64(3), int64(2), object(11)
# memory usage: 1.5+ GB

# %%
df.isna().sum()
# Out:
# amount                      0
# block_hash                  0
# block_number                0
# block_timestamp             0
# contract_type             670
# from_address                0
# log_index                6254
# operator             10565202
# to_address                  0
# token_address               0
# token_id                   77
# transaction_hash            0
# transaction_index       13520
# transaction_type            0
# value                       0
# verified                    0
# is_batch                    0
# dtype: int64

# %%
# %%time
df = df[~df.token_id.isna()]
df = df[~df.contract_type.isin(['ERC1155', 'ERC165'])]
df['nft_id'] = df['token_address'].str.cat(df['token_id'], sep="/")
df['block_timestamp'] = pd.to_datetime(df.block_timestamp)
df = df[~df.is_batch]
df = df[df.value > 0]
# Out:
# CPU times: user 7.04 s, sys: 1.57 s, total: 8.61 s
# Wall time: 8.69 s

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1205442 entries, 2 to 12469144
# Data columns (total 18 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   amount             1205442 non-null  object
#  1   block_hash         1205442 non-null  object
#  2   block_number       1205442 non-null  int64
#  3   block_timestamp    1205442 non-null  datetime64[ns, UTC]
#  4   contract_type      1205299 non-null  object
#  5   from_address       1205442 non-null  object
#  6   log_index          1204383 non-null  float64
#  7   operator           0 non-null        object
#  8   to_address         1205442 non-null  object
#  9   token_address      1205442 non-null  object
#  10  token_id           1205442 non-null  object
#  11  transaction_hash   1205442 non-null  object
#  12  transaction_index  1201949 non-null  float64
#  13  transaction_type   1205442 non-null  object
#  14  value              1205442 non-null  float64
#  15  verified           1205442 non-null  int64
#  16  is_batch           1205442 non-null  bool
#  17  nft_id             1205442 non-null  object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(3), int64(2), object(11)
# memory usage: 166.7+ MB

# %%
def load_non_batch_sales_data(start_date: date, end_date: date, local_path: string) -> pd.DataFrame:
    """Loads non batch sales from NFT token transfer data 
        with value in ether from start_date to end_date

    Args:
        start_date: an inclusive start date for nft token transfers
        end_date: an inclusive end date for nft token transfers
        local_path: a local path where the nft toke transfer date is located
    
    Returns:
        concatenated transfers dataframe for [start_date, end_date]

    Raises:
        ValueError: if start_date is greater than end_date
        FileNotFoundError: if local_path does not exist or if no csv file is found in the local_path
    """
    if not os.path.exists(local_path):
        raise FileNotFoundError("The local_path does not exist")
    if start_date > end_date:
        raise ValueError("The 'end_date' should be equal to or greather than 'start_date'")

    transfers_list = []
    for date_ in iterate_dates(start_date, end_date):
        fname = os.path.join(local_path, "nft_token_transfers={}.csv".format(date_.strftime("%Y-%m-%d")))
        if os.path.exists(fname):
            transfers = pd.read_csv(fname, low_memory=False)
            transfers = convert_value_from_wei(transfers, 'ether')
            transfers = transfers[~transfers.is_batch]
            transfers = transfers[transfers.value > 0]
            transfers_list.append(transfers)
        else:
            logging.error(f"{fname} does not exist")
    
    if transfers_list:
        return pd.concat(transfers_list, ignore_index=True)
    else:
        raise FileNotFoundError(f"No csv file was loaded from {local_path}")

# %%
# %%time
df = load_non_batch_sales_data(start_date, end_date, local_path)
# Out:
# CPU times: user 42.8 s, sys: 2.65 s, total: 45.5 s
# Wall time: 45.5 s

# %%
# %%time
df = df[~df.token_id.isna()]
df = df[~df.contract_type.isin(['ERC1155', 'ERC165'])]
df['nft_id'] = df['token_address'].str.cat(df['token_id'], sep="/")
df['block_timestamp'] = pd.to_datetime(df.block_timestamp)
# Out:
# CPU times: user 895 ms, sys: 58.5 ms, total: 953 ms
# Wall time: 952 ms

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1205442 entries, 0 to 1313798
# Data columns (total 18 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   amount             1205442 non-null  object
#  1   block_hash         1205442 non-null  object
#  2   block_number       1205442 non-null  int64
#  3   block_timestamp    1205442 non-null  datetime64[ns, UTC]
#  4   contract_type      1205299 non-null  object
#  5   from_address       1205442 non-null  object
#  6   log_index          1204383 non-null  float64
#  7   operator           0 non-null        object
#  8   to_address         1205442 non-null  object
#  9   token_address      1205442 non-null  object
#  10  token_id           1205442 non-null  object
#  11  transaction_hash   1205442 non-null  object
#  12  transaction_index  1201949 non-null  float64
#  13  transaction_type   1205442 non-null  object
#  14  value              1205442 non-null  float64
#  15  verified           1205442 non-null  int64
#  16  is_batch           1205442 non-null  bool
#  17  nft_id             1205442 non-null  object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(3), int64(2), object(11)
# memory usage: 166.7+ MB

# %% [markdown]
# ### Get purchases and sales

# %%
genesis_addresses = [
    "0x0000000000000000000000000000000000000002",
    "0x0000000000000000000000000000000000000003",
    "0x0000000000000000000000000000000000000004",
    "0x0000000000000000000000000000000000000005",
    "0x0000000000000000000000000000000000000006",
    "0x0000000000000000000000000000000000000007",
    "0x0000000000000000000000000000000000000008",
    "0x0000000000000000000000000000000000000009",
    "0x0000000000000000000000000000000000000000",
    "0x3333333333333333333333333333333333333333",
    "0x4444444444444444444444444444444444444444",
    "0x8888888888888888888888888888888888888888",
]
burn_addresses = [
    "0x000000000000000000000000000000000000cdad",
    "0x000000000000000000000000000000000000dead",
    "0x0000000000000000000000000000000000000001",
    "0x0000000000000000000000000000000000000002",
    "0x0000000000000000000000000000000000000003",
    "0x0000000000000000000000000000000000000004",
    "0x0000000000000000000000000000000000000005",
    "0x0000000000000000000000000000000000000006",
    "0x0000000000000000000000000000000000000007",
    "0x0000000000000000000000000000000000000008",
    "0x0000000000000000000000000000000000000009",
    "0x0000000000000000000000000000000000000000",
    "0x00000000000000000000045261d4ee77acdb3286",
    "0x0123456789012345678901234567890123456789",
    "0x1111111111111111111111111111111111111111",
    "0x1234567890123456789012345678901234567890",
    "0x2222222222222222222222222222222222222222",
    "0x3333333333333333333333333333333333333333",
    "0x4444444444444444444444444444444444444444",
    "0x6666666666666666666666666666666666666666",
    "0x8888888888888888888888888888888888888888",
    "0xaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa",
    "0xbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb",
    "0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee",
    "0xffffffffffffffffffffffffffffffffffffffff",
    "0xdead000000000000000042069420694206942069",
]
null_addresses = list(set(genesis_addresses + burn_addresses))

# %%
# %%time
nft_purchases = df[~df.to_address.isin(null_addresses)]\
                    [['to_address', 'block_timestamp', 'token_address', 'value', 'nft_id']]\
                    .rename(columns={'to_address': 'wallet_address',
                                     'block_timestamp': 'purchase_time', 
                                     'token_address': 'collection_id', 
                                     'value': 'purchase_value'})
nft_purchases = nft_purchases[~nft_purchases.index.duplicated(keep='first')]
# Out:
# CPU times: user 510 ms, sys: 39.2 ms, total: 549 ms
# Wall time: 549 ms

# %%
# %%time
nft_sales = df[~df.from_address.isin(null_addresses)]\
                    [['from_address', 'block_timestamp', 'value', 'nft_id']]\
                    .rename(columns={'from_address': 'wallet_address',
                                     'block_timestamp': 'sale_time',
                                     'value': 'sale_value'})
nft_sales = nft_sales[~nft_sales.index.duplicated(keep='first')]
# Out:
# CPU times: user 260 ms, sys: 27 ms, total: 287 ms
# Wall time: 286 ms

# %%
# %%time
nft_pns = nft_purchases.merge(nft_sales, how='outer', on=['wallet_address','nft_id'])
# Out:
# CPU times: user 899 ms, sys: 78.8 ms, total: 978 ms
# Wall time: 987 ms

# %%
nft_pns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1954643 entries, 0 to 1954642
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   wallet_address  object
#  1   purchase_time   datetime64[ns, UTC]
#  2   collection_id   object
#  3   purchase_value  float64
#  4   nft_id          object
#  5   sale_time       datetime64[ns, UTC]
#  6   sale_value      float64
# dtypes: datetime64[ns, UTC](2), float64(2), object(3)
# memory usage: 119.3+ MB

# %%
# %%time
nft_pns['hold_time'] = nft_pns['sale_time'] - nft_pns['purchase_time']
nft_pns = nft_pns[(nft_pns.hold_time.isna()) | (nft_pns.hold_time > pd.Timedelta(0,'s'))]
# Out:
# CPU times: user 190 ms, sys: 36.6 ms, total: 226 ms
# Wall time: 226 ms

# %%
# %%time
is_owned = nft_pns.sale_time.isna().rename('is_owned')
nft_pns = nft_pns.join(is_owned)
# Out:
# CPU times: user 96 ms, sys: 17.4 ms, total: 113 ms
# Wall time: 112 ms

# %% [markdown]
# ### Whales and NFT Collectors

# %%
candidate_pns = nft_pns[nft_pns.is_owned].copy()

# %%
candidate_pns
# Out:
#                                      wallet_address             purchase_time  \
# 0        0x1240b283c420621015f69f292d8fdb523a52772e 2022-09-25 23:59:47+00:00
# 2        0xbaaf84e8e2467f4c71506cd8ea54d367f53d9ee9 2022-09-25 23:59:47+00:00
# 3        0x7103964efae2acd944ce03ea0e3c3f4ad2c4a2ae 2022-09-25 23:59:47+00:00
# 4        0x560745f9a1cec04879c4a85299859db336da903c 2022-09-25 23:59:47+00:00
# 6        0xf77bb93d483b991a3bcb72e8d17f619774582944 2022-09-25 23:59:35+00:00
# ...                                             ...                       ...
# 1215359  0x092cff73c77a9de794d25b0088ded0e430733dbb 2022-10-24 23:59:59+00:00
# 1215360  0xa3dbde2b97f164771c39ac5f8cbdc9a7e158f483 2022-10-24 23:59:59+00:00
# 1215361  0xb1a5e908cbaabfea9f0baada6614583d03b74b08 2022-10-24 23:59:59+00:00
# 1215362  0xa5c90a02f955e02c21b29060d5f8a9725b50f2b2 2022-10-24 23:59:59+00:00
# 1215363  0xee432788ab11935ab66e5a71b8ecc333694957ac 2022-10-24 23:59:59+00:00
#
#                                       collection_id  purchase_value  \
# 0        0xd1169e5349d1cb9941f3dcba135c8a4b9eacfdde         0.58999
# 2        0xc101916cd9ddeac5a6f915eed033b1b6e4a637cb         0.41000
# 3        0xc36442b4a4522e871399cd717abdd847ab11fe88         0.01500
# 4        0xb9b2267d3c35d1fb0bbf752b6205eea91a82cd84         0.00400
# 6        0xfd4b8f7522c9398c0ad38ad63548cd8b226feb93         0.01200
# ...                                             ...             ...
# 1215359  0x67421c8622f8e38fe9868b4636b8dc855347d570         0.10990
# 1215360  0x3c9075f574edc2f630f918ebac5ccf1095d82cc2         0.01000
# 1215361  0xd88b8b8c45a0531229dbbf93b8c503bfbe17e86a         0.03800
# 1215362  0x1c3ec75c53eca5acf20b0a64bab2c6d163bb08cf         0.00740
# 1215363  0xf8e37640d57b5719f14452c8afc29e50606e36c1         0.01000
#
#                                                     nft_id sale_time  \
# 0        0xd1169e5349d1cb9941f3dcba135c8a4b9eacfdde/171...       NaT
# 2          0xc101916cd9ddeac5a6f915eed033b1b6e4a637cb/7021       NaT
# 3        0xc36442b4a4522e871399cd717abdd847ab11fe88/323988       NaT
# 4          0xb9b2267d3c35d1fb0bbf752b6205eea91a82cd84/4213       NaT
# 6           0xfd4b8f7522c9398c0ad38ad63548cd8b226feb93/291       NaT
# ...                                                    ...       ...
# 1215359    0x67421c8622f8e38fe9868b4636b8dc855347d570/2629       NaT
# 1215360    0x3c9075f574edc2f630f918ebac5ccf1095d82cc2/2558       NaT
# 1215361    0xd88b8b8c45a0531229dbbf93b8c503bfbe17e86a/1286       NaT
# 1215362     0x1c3ec75c53eca5acf20b0a64bab2c6d163bb08cf/647       NaT
# 1215363      0xf8e37640d57b5719f14452c8afc29e50606e36c1/55       NaT
#
#          sale_value hold_time  is_owned
# 0               NaN       NaT      True
# 2               NaN       NaT      True
# 3               NaN       NaT      True
# 4               NaN       NaT      True
# 6               NaN       NaT      True
# ...             ...       ...       ...
# 1215359         NaN       NaT      True
# 1215360         NaN       NaT      True
# 1215361         NaN       NaT      True
# 1215362         NaN       NaT      True
# 1215363         NaN       NaT      True
#
# [1012076 rows x 9 columns]

# %%
candidate_pns['is_high_value'] = candidate_pns.purchase_value > candidate_pns.purchase_value.quantile(.975)

# %%
candidates = candidate_pns.groupby('wallet_address').is_high_value.sum().rename('num_high_value').to_frame()

# %%
candidates['num_collections'] = candidate_pns.groupby('wallet_address').collection_id.nunique()

# %%
candidates['num_owned'] = candidate_pns.groupby('wallet_address').is_owned.sum()

# %%
hv_cut = candidates.num_high_value.quantile(.95)

# %%
nc_cut = candidates.num_collections.quantile(.9)

# %%
nc_cut
# Out:
# 5.0

# %%
candidates
# Out:
#                                             num_high_value  num_collections  \
# wallet_address
# 0x0000000000006e543164be036824fcf832e67e47               0                1
# 0x000000000000d34c44564053af35e4fe271d0caa              12                1
# 0x00000000000a01757661bd51345cd95c40320480               0                2
# 0x00000000008c1ed3b68ae8bd7e74e595bd11b066               0                2
# 0x0000000000a0136c855efb4596d1da5f5b703262               0                1
# ...                                                    ...              ...
# 0xfffed1a6b1e22c7ddb1ee12be2958dfd32083e36               0                2
# 0xffff41988852d624b0e640e895eb4d18f7da077e               0                1
# 0xffff431202204ea74698b0fb1ebfe6a841206bcb               0                1
# 0xffffe388e1e4cfaab94f0b883d28b8a424cb45a1               0                2
# 0xffffffff7a5cb56bbccb9dfaff17bb2b26a3d71c               0                2
#
#                                             num_owned
# wallet_address
# 0x0000000000006e543164be036824fcf832e67e47          1
# 0x000000000000d34c44564053af35e4fe271d0caa         12
# 0x00000000000a01757661bd51345cd95c40320480          2
# 0x00000000008c1ed3b68ae8bd7e74e595bd11b066          2
# 0x0000000000a0136c855efb4596d1da5f5b703262          1
# ...                                               ...
# 0xfffed1a6b1e22c7ddb1ee12be2958dfd32083e36         10
# 0xffff41988852d624b0e640e895eb4d18f7da077e          1
# 0xffff431202204ea74698b0fb1ebfe6a841206bcb          1
# 0xffffe388e1e4cfaab94f0b883d28b8a424cb45a1          2
# 0xffffffff7a5cb56bbccb9dfaff17bb2b26a3d71c          2
#
# [259396 rows x 3 columns]

# %%
whales = candidates[(candidates['num_high_value'] > hv_cut) & (candidates['num_collections'] > nc_cut)]

# %%
whales.describe()
# Out:
#        num_high_value  num_collections    num_owned
# count      679.000000       679.000000   679.000000
# mean         4.521355        13.369661    33.322533
# std          7.775371        16.705157    65.140492
# min          2.000000         6.000000     6.000000
# 25%          2.000000         7.000000    12.000000
# 50%          3.000000         9.000000    19.000000
# 75%          4.000000        13.000000    34.500000
# max        149.000000       305.000000  1280.000000

# %%
whales
# Out:
#                                             num_high_value  num_collections  \
# wallet_address
# 0x003ef9575e9535636651c0c15ea376266daa09f8               2                7
# 0x0064f02799ea7748a9b51b5e78bcd274d9e7d0a1               5                6
# 0x00e484da1156202e9dd341ad7ea9c908bb919e96               7               13
# 0x013598ea3fd28608c23ebac199c5b4218e2ade3a              12               16
# 0x016099f9c894285b4bcf82424a4dbde44195ebbc               5                8
# ...                                                    ...              ...
# 0xff1777854bdc3507d581e3a762b0f85832302611               6                6
# 0xff567d26a66a556afe5b9183db01370aa78d7bda               7               12
# 0xffb6d97bd1e7b7bd08595096d15037401a1f416b               5                6
# 0xffba913bb056544b75e57312ec3eae2528c285e1               2                6
# 0xfffc9d8e1c9b4d8aceb50fcba4a701413bb20099               4                6
#
#                                             num_owned
# wallet_address
# 0x003ef9575e9535636651c0c15ea376266daa09f8         28
# 0x0064f02799ea7748a9b51b5e78bcd274d9e7d0a1          6
# 0x00e484da1156202e9dd341ad7ea9c908bb919e96         74
# 0x013598ea3fd28608c23ebac199c5b4218e2ade3a         38
# 0x016099f9c894285b4bcf82424a4dbde44195ebbc        131
# ...                                               ...
# 0xff1777854bdc3507d581e3a762b0f85832302611         13
# 0xff567d26a66a556afe5b9183db01370aa78d7bda         25
# 0xffb6d97bd1e7b7bd08595096d15037401a1f416b         10
# 0xffba913bb056544b75e57312ec3eae2528c285e1          8
# 0xfffc9d8e1c9b4d8aceb50fcba4a701413bb20099          7
#
# [679 rows x 3 columns]

# %%
whales.to_csv(user_local_path+'/whales.csv')

# %%
no_cut = candidates['num_owned'].quantile(.98)

# %%
collectors = candidates[(candidates['num_collections'] > nc_cut) & (candidates['num_owned'] > no_cut)]

# %%
collectors
# Out:
#                                             num_high_value  num_collections  \
# wallet_address
# 0x0013b99e50372d609f1e1a8af83544878e99fcf7               0               19
# 0x0013fadb2294a00005b334f40f767a3eb4f6bbc4               0               12
# 0x001a181ab8c41045e26dd2245ffcc12818ea742f               0               30
# 0x002c43d42c425e20052f0db04fd01dc66d43c8f5               0               12
# 0x00385f60f4b5234e96989805af7328f7afd742b1               0               30
# ...                                                    ...              ...
# 0xff67ddc700a58450edcfd7055028e190b1b31e45               0               10
# 0xffc226d4c72e637582166ae68b7c638d46176585               0               15
# 0xffd19e673ca7d6780640c9c659dacb07578557e8               0               20
# 0xffdef5e9eeaceac0800a2f784105105dbaf1d884               1              107
# 0xffe973085371376e187f937abe7e2175876483e2               0               51
#
#                                             num_owned
# wallet_address
# 0x0013b99e50372d609f1e1a8af83544878e99fcf7         50
# 0x0013fadb2294a00005b334f40f767a3eb4f6bbc4         30
# 0x001a181ab8c41045e26dd2245ffcc12818ea742f         73
# 0x002c43d42c425e20052f0db04fd01dc66d43c8f5         32
# 0x00385f60f4b5234e96989805af7328f7afd742b1         39
# ...                                               ...
# 0xff67ddc700a58450edcfd7055028e190b1b31e45         28
# 0xffc226d4c72e637582166ae68b7c638d46176585         49
# 0xffd19e673ca7d6780640c9c659dacb07578557e8         27
# 0xffdef5e9eeaceac0800a2f784105105dbaf1d884        175
# 0xffe973085371376e187f937abe7e2175876483e2         60
#
# [4058 rows x 3 columns]

# %%
collectors.to_csv(user_local_path+'/collectors.csv')

# %%
collectors.describe()
# Out:
#        num_high_value  num_collections    num_owned
# count     4058.000000      4058.000000  4058.000000
# mean         0.463036        21.439133    51.011582
# std          3.428230        14.428130    44.889678
# min          0.000000         6.000000    26.000000
# 25%          0.000000        12.000000    30.000000
# 50%          0.000000        19.000000    38.000000
# 75%          0.000000        26.000000    55.000000
# max        149.000000       305.000000  1280.000000

# %%
len(set(collectors.index).intersection(set(whales.index)))
# Out:
# 243

# %% [markdown]
# ### NFT Flippers

# %%
candidate_pns = nft_pns[~nft_pns['hold_time'].isna()].copy()

# %%
candidate_pns.hold_time.quantile(.3)
# Out:
# Timedelta('0 days 02:04:12')

# %%
candidate_pns['is_flipped'] = candidate_pns.hold_time < candidate_pns.hold_time.quantile(.3)

# %%
candidate_pns['profit'] = candidate_pns['sale_value'] - candidate_pns['purchase_value']

# %%
candidate_pns['is_profit'] = candidate_pns['profit'] > 0

# %%
candidate_pns
# Out:
#                                      wallet_address             purchase_time  \
# 1        0xff452cc8ff7deb713b6cf5ac5aa6085c0a606786 2022-09-25 23:59:47+00:00
# 5        0x92237f6261db6081421da708f1c0c58fd784e6f3 2022-09-25 23:59:35+00:00
# 9        0x3a1309b56e851e4ce35f06bf8a59026508b1bb66 2022-09-25 23:59:35+00:00
# 17       0xcb37c667383e37cf11a0c1f30bed85db84ee7c80 2022-09-25 23:59:11+00:00
# 25       0x81147564788a81bb4aa78b7ecb35ce849fcb9aa9 2022-09-25 23:58:59+00:00
# ...                                             ...                       ...
# 1214954  0x763d39179b63fe0ad612a7e7c963a6e69b2c9c95 2022-10-25 00:24:47+00:00
# 1214980  0x8e49d11acd326f242fa48509fd3b40f07c6f9e6d 2022-10-25 00:23:11+00:00
# 1215153  0x08e1e8fee2d1862c3e45fc246488b1af179502e1 2022-10-25 00:10:35+00:00
# 1215233  0xe58299ab678228081d9c682bc77d5dd6b1f3d6a5 2022-10-25 00:07:47+00:00
# 1215266  0xb013fcbbf0ab188b98f4aa28ce96c94f9b737478 2022-10-25 00:05:35+00:00
#
#                                       collection_id  purchase_value  \
# 1        0x79471bb4cbb351a17fa1eadb5b77aa76795c423a         0.01870
# 5        0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85         0.00080
# 9        0x9121c7f5976692bc7f97cd380d19a7a7e1d0e0f5         0.00100
# 17       0xf13f29330dca76be26a6c7e268da836aef978e11         0.19300
# 25       0xf13f29330dca76be26a6c7e268da836aef978e11         0.20000
# ...                                             ...             ...
# 1214954  0x248139afb8d3a2e16154fbe4fb528a3a214fd8e7         0.13000
# 1214980  0xeb4e856f69158052ac0aaf7dc26f63dcb1ee067f         0.75000
# 1215153  0x386358700ecd5e1b157494c4124dc545d9654e59         0.00089
# 1215233  0xbbaec9eac5c2cb4464be1f09158d9d61ac429a20         0.00660
# 1215266  0x3e7fc44e25c07be3d67c241e6e59cb838df2f892         0.35000
#
#                                                     nft_id  \
# 1          0x79471bb4cbb351a17fa1eadb5b77aa76795c423a/1810
# 5        0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85/389...
# 9          0x9121c7f5976692bc7f97cd380d19a7a7e1d0e0f5/8725
# 17          0xf13f29330dca76be26a6c7e268da836aef978e11/280
# 25          0xf13f29330dca76be26a6c7e268da836aef978e11/649
# ...                                                    ...
# 1214954    0x248139afb8d3a2e16154fbe4fb528a3a214fd8e7/1079
# 1214980    0xeb4e856f69158052ac0aaf7dc26f63dcb1ee067f/1339
# 1215153    0x386358700ecd5e1b157494c4124dc545d9654e59/1831
# 1215233     0xbbaec9eac5c2cb4464be1f09158d9d61ac429a20/262
# 1215266     0x3e7fc44e25c07be3d67c241e6e59cb838df2f892/956
#
#                         sale_time  sale_value        hold_time  is_owned  \
# 1       2022-10-01 09:04:47+00:00      0.0125  5 days 09:05:00     False
# 5       2022-10-16 23:49:23+00:00      0.0008 20 days 23:49:48     False
# 9       2022-10-08 11:18:11+00:00      0.0030 12 days 11:18:36     False
# 17      2022-09-26 14:24:35+00:00      0.2155  0 days 14:25:24     False
# 25      2022-09-26 00:40:59+00:00      0.3330  0 days 00:42:00     False
# ...                           ...         ...              ...       ...
# 1214954 2022-10-25 12:37:11+00:00      0.1390  0 days 12:12:24     False
# 1214980 2022-10-25 03:16:59+00:00      0.7520  0 days 02:53:48     False
# 1215153 2022-10-25 10:01:11+00:00      0.0010  0 days 09:50:36     False
# 1215233 2022-10-25 00:16:11+00:00      0.0400  0 days 00:08:24     False
# 1215266 2022-10-25 19:58:23+00:00      0.3100  0 days 19:52:48     False
#
#          is_flipped   profit  is_profit
# 1             False -0.00620      False
# 5             False  0.00000      False
# 9             False  0.00200       True
# 17            False  0.02250       True
# 25             True  0.13300       True
# ...             ...      ...        ...
# 1214954       False  0.00900       True
# 1214980       False  0.00200       True
# 1215153       False  0.00011       True
# 1215233        True  0.03340       True
# 1215266       False -0.04000      False
#
# [193011 rows x 12 columns]

# %%
candidates = candidate_pns.groupby('wallet_address').is_flipped.sum().rename('num_flipped').to_frame()

# %%
candidates['num_collection'] = candidate_pns.groupby('wallet_address').collection_id.nunique()

# %%
candidates['num_profit'] = candidate_pns.groupby('wallet_address').is_profit.sum()

# %%
candidates['avg_profit'] = candidate_pns.groupby('wallet_address').profit.mean()
candidates['tot_profit'] = candidate_pns.groupby('wallet_address').profit.sum()

# %%
candidates.describe()
# Out:
#         num_flipped  num_collection    num_profit    avg_profit    tot_profit
# count  57848.000000    57848.000000  57848.000000  57848.000000  57848.000000
# mean       1.000899        2.306873      2.212989      0.052212      0.246014
# std        3.540099        3.642366     10.726882      0.584790     96.862618
# min        0.000000        1.000000      0.000000    -68.886936 -11965.600000
# 25%        0.000000        1.000000      1.000000      0.000079      0.000100
# 50%        0.000000        1.000000      1.000000      0.015951      0.025600
# 75%        1.000000        2.000000      2.000000      0.046000      0.100000
# max      259.000000      139.000000   1660.000000     22.367075  13319.778256

# %%
nc_cut = candidates.num_collection.quantile(.90)

# %%
nc_cut
# Out:
# 5.0

# %%
nf_cut = candidates.num_flipped.quantile(.98)
nf_cut
# Out:
# 7.0

# %%
nft_flippers = candidates[(candidates.num_collection > nc_cut) & (candidates.num_flipped > nf_cut)]

# %%
nft_flippers.to_csv(user_local_path+'/flippers.csv')

# %%
nft_flippers.describe()
# Out:
#        num_flipped  num_collection  num_profit  avg_profit  tot_profit
# count   946.000000      946.000000  946.000000  946.000000  946.000000
# mean     17.978858       20.322410   23.403805    0.021635    0.752080
# std      17.650324       13.104653   22.073464    0.091373    4.723097
# min       8.000000        6.000000    2.000000   -0.860067  -50.743963
# 25%       9.000000       11.000000   11.000000    0.004635    0.103274
# 50%      12.000000       17.000000   17.000000    0.011770    0.305311
# 75%      20.000000       25.000000   27.000000    0.023722    0.755104
# max     259.000000      139.000000  298.000000    2.019387  129.240750

# %%
nft_flippers
# Out:
#                                             num_flipped  num_collection  \
# wallet_address
# 0x0000a83deaa073245cfbde660fd8daf09d78de00            9              13
# 0x00385f60f4b5234e96989805af7328f7afd742b1            9              25
# 0x004eb19e583c7913e8c30e413ab11b3140b5a3ba           11              10
# 0x00794b7b900165f452e2b02cc191e6b8b6f8f869            9              18
# 0x01660cc34a2ae458dc040589f65d3b31cb08b5fb           17              18
# ...                                                 ...             ...
# 0xff169015209d26c867edb261e702df4446674507            8               6
# 0xff274763062ab364fe17d17cc1cc10fa9e41e040           24              24
# 0xffdef5e9eeaceac0800a2f784105105dbaf1d884           31              45
# 0xffe973085371376e187f937abe7e2175876483e2            8              28
# 0xfff0eced57a314066ee067d4a8538bc6fefa28dd           12              15
#
#                                             num_profit  avg_profit  tot_profit
# wallet_address
# 0x0000a83deaa073245cfbde660fd8daf09d78de00          22    0.000052    0.002405
# 0x00385f60f4b5234e96989805af7328f7afd742b1          12    0.000619    0.022300
# 0x004eb19e583c7913e8c30e413ab11b3140b5a3ba           9    0.000799    0.010390
# 0x00794b7b900165f452e2b02cc191e6b8b6f8f869          14    0.000496    0.010410
# 0x01660cc34a2ae458dc040589f65d3b31cb08b5fb          31    0.012573    0.502900
# ...                                                ...         ...         ...
# 0xff169015209d26c867edb261e702df4446674507           8    0.000500    0.008506
# 0xff274763062ab364fe17d17cc1cc10fa9e41e040          25    0.013865    0.388217
# 0xffdef5e9eeaceac0800a2f784105105dbaf1d884          70    0.029537    2.481069
# 0xffe973085371376e187f937abe7e2175876483e2          20    0.007299    0.248162
# 0xfff0eced57a314066ee067d4a8538bc6fefa28dd          10   -0.001300   -0.029890
#
# [946 rows x 5 columns]

# %%
nf_cut = nft_flippers.num_profit.quantile(.5)
ap_cut = nft_flippers.avg_profit.quantile(.5)

# %%
profitable_nft_flippers = nft_flippers[(nft_flippers.num_flipped > nf_cut) & (nft_flippers.avg_profit > ap_cut)]

# %%
profitable_nft_flippers.to_csv(user_local_path+'/profitable_flippers.csv')

# %%
profitable_nft_flippers.describe()
# Out:
#        num_flipped  num_collection  num_profit  avg_profit  tot_profit
# count   152.000000      152.000000  152.000000  152.000000  152.000000
# mean     39.197368       32.559211   49.335526    0.042923    2.688910
# std      29.635543       17.328052   36.208913    0.163710   10.469720
# min      18.000000        9.000000   16.000000    0.012186    0.383121
# 25%      22.000000       21.000000   28.750000    0.016277    0.754880
# 50%      28.000000       27.500000   40.000000    0.022108    1.246962
# 75%      45.000000       39.000000   57.250000    0.031568    2.417686
# max     259.000000      139.000000  298.000000    2.019387  129.240750
